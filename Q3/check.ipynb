# %%
import pandas as pd
import numpy as np
# In[2]:
wd = pd.read_csv('winequalityN.csv')
# In[3]:
wd.head(5)
# In[4]:
print(f'Number of empty records: {wd.isna().sum().sum()}')
# In[5]:
wd.dropna(inplace=True)
# In[6]:
wd_des = wd.describe()
# In[7]:
for i in wd_des.columns:
  if wd_des[i]['mean']!=0 or wd_des[i]['std']!=1 :
    print('standardization needed in ',i)
    
# In[8]:
X = wd.iloc[:,:-1].values
y = wd.iloc[:,-1].values
display("X values ",X[0])
print('Y values ',y)
# In[9]:
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder',OneHotEncoder(),[0])],remainder
= 'passthrough')
print(ct)
X = np.array(ct.fit_transform(X))
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X = ss.fit_transform(X)
# In[11]:
df=pd.DataFrame(X,columns=wd.columns)
display(df)
df.describe()
# Out:
# Number of empty records: 38
# standardization needed in  fixed acidity
# standardization needed in  volatile acidity
# standardization needed in  citric acid
# standardization needed in  residual sugar
# standardization needed in  chlorides
# standardization needed in  free sulfur dioxide
# standardization needed in  total sulfur dioxide
# standardization needed in  density
# standardization needed in  pH
# standardization needed in  sulphates
# standardization needed in  alcohol
# standardization needed in  quality
# 'X values '
# array(['white', 7.0, 0.27, 0.36, 20.7, 0.045, 45.0, 170.0, 1.001, 3.0,
#        0.45, 8.8], dtype=object)
# Y values  [6 6 6 ... 6 5 6]
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('encoder', OneHotEncoder(), [0])])
#           type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    -0.571931       0.571931         -0.167786    -0.422710        0.283959
# ...
