# %% [markdown]
# Name: Shahnwaz Khan
# Roll: Ac-1272
# Practical 3

# %%
import pandas as pd

# %% [markdown]
# Q3 Load the data from wine dataset. Check whether all attributes are standardized or not (mean
# is 0 and standard deviation is 1). If not, standardize the attributes. Do the same with Iris dataset.

# %%
data=pd.read_csv('winequalityN.csv')
# Drop categorical type column
data.drop(columns=['type'],inplace=True)
data2=data.copy()
display(data)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# check if attributes are standarized or not
d=data.describe()
for i in d.columns:
  if d[i]['mean']!=0 or d[i]['std']!=1 :
    print(i, ' column is not standarized.')
# Out:
# fixed acidity  column is not standarized.
# volatile acidity  column is not standarized.
# citric acid  column is not standarized.
# residual sugar  column is not standarized.
# chlorides  column is not standarized.
# free sulfur dioxide  column is not standarized.
# total sulfur dioxide  column is not standarized.
# density  column is not standarized.
# pH  column is not standarized.
# sulphates  column is not standarized.
# alcohol  column is not standarized.
# quality  column is not standarized.

# %%
# second method
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
data=ss.fit_transform(data2)
data=pd.DataFrame(data,columns=data2.columns)
display(data)
display(data.describe())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.167030         -0.423303     0.284180        3.206483  -0.315173
# 1         -0.706883         -0.241083     0.146489       -0.808012  -0.200996
# 2          0.681310         -0.362563     0.559560        0.305958  -0.172452
# 3         -0.012786         -0.666262     0.008799        0.642251   0.055902
# 4         -0.012786         -0.666262     0.008799        0.642251   0.055902
# ...             ...               ...          ...             ...        ...
# 6492      -0.784004          1.581115    -1.643483       -0.723939   0.969318
# 6493      -1.015370          1.277415    -1.505793       -0.681902   0.170079
# 6494      -0.706883          1.034456    -1.299258       -0.660884   0.569698
# 6495      -1.015370          1.854445    -1.368103       -0.723939   0.541154
# 6496      -0.938248         -0.180343     1.041476       -0.387646   0.312800
#
# ...

# %%
import seaborn as sns
iris=sns.load_dataset('iris')
display(iris)
display(iris.describe())
iris.drop(columns=['species'],inplace=True)
data=ss.fit_transform(iris)
data=pd.DataFrame(data,columns=iris.columns)
display(data)
display(data.describe())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
#        sepal_length  sepal_width  petal_length  petal_width
# ...
